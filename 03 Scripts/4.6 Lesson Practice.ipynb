# %% [markdown]
# # 4.6 Combining and Exporting Data Practice
#
# ### 1. Create data dictionary
# ### 2. Create dictionary into dataframe
# ### 3. Concatenate your dataframes
# ### 4. Merge Dataframes

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ##### 1. Create data dictionary

# %%
#Define a dictionary containing January 2020 data
data1 = {'customer_id' :['6732', '767', '890', '635'], 
        'month': ['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
        'purchased_meat':[0, 13, 3, 4],
        'purchased_alcohol': [1, 2, 10, 0], 
        'purchased_snacks': [10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %% [markdown]
# ##### 2. Create dictionary into dataframe

# %%
df = pd.DataFrame(data1, index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2, index=[0, 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ##### Concatenate your dataframes
# 1. Create list of frames you want to combine
# 2. Concatenate using pd.concat()

# %%
frames = [df, df_1]

# %%
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ##### 3. Merge dataframes

# %%
df_merged = df_concat.merge(df, on=['customer_id', 'month'], indicator=True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x  purchased_meat_y  purchased_alcohol_y  \
# 0                  10                 0                    1
# 1                   5                13                    2
# 2                   1                 3                   10
# 3                   7                 4                    0
#
#    purchased_snacks_y _merge
# 0                  10   both
# 1                   5   both
# 2                   1   both
# 3                   7   both

# %%
df_merged['_merge'].value_counts()
# Out:
# both          4
# left_only     0
# right_only    0
# Name: _merge, dtype: int64

# %%
# Test merge without overwriting
pd.merge(df,df_concat, on = ['customer_id', 'month'], indicator = True)
# Out:
#   customer_id   month  purchased_meat_x  purchased_alcohol_x  \
# 0        6732  Jan-20                 0                    1
# 1         767  Jan-20                13                    2
# 2         890  Jan-20                 3                   10
# 3         635  Jan-20                 4                    0
#
#    purchased_snacks_x  purchased_meat_y  purchased_alcohol_y  \
# 0                  10                 0                    1
# 1                   5                13                    2
# 2                   1                 3                   10
# 3                   7                 4                    0
#
#    purchased_snacks_y _merge
# 0                  10   both
# 1                   5   both
# 2                   1   both
# 3                   7   both
