# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Import path
path= r'/Users/owner/Documents/05_2023_Instacart_Basket_Analysis'

# %%
#Import orders_products_merged
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# # Using if, then statements and creating variables

# %%
#Work with smaller dataset
df = df_orders_products_merged[:1000000]

# %%
#Check Shape
df.shape
# Out:
# (1000000, 13)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices
# 0         Soda        77              7     9.0
# 1         Soda        77              7     9.0
# ...

# %%
#Define price_label column; if, then (:); elif=else if 
def price_label(row):
    if row['prices'] <=5:
        return 'Low-range product'
    elif (row['prices']>5) and (row['prices']<=15):
        return 'Mid-range product'
    elif row['prices']>15:
        return 'High-range product'
    else: return 'Not enough data'

# %% [markdown]
# This means:
#
# If the value within the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.”
#
# Or else, if the value within the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
#
# Or else, if the value of the “prices” column within the given row is greater than 15, then return the string “High-range product.”
#
# Or else, return the string “Not enough data.”

# %%
#apply price label column to dataframe
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/l9/r6mq8fk51_z31zfmx7sx2ggc0000gn/T/ipykernel_16693/2679094843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#Check Shape
df.shape
# Out:
# (1000000, 14)

# %%
#Count values in price_range column
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#Check most expensive item in price column
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If-Statements with the loc() Function

# %%
#Using locate [loc()] function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %% [markdown]
# if = df.loc[df['prices'] > 15,
#
# then = 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %% [markdown]
# if = df.loc[(df['prices'] <= 15) & (df['prices'] > 5),
#
# then = 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# if= df.loc[df['prices'] <= 5
#
# then= 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
#Using locate [loc()] function in full dataframe
df_orders_products_merged.loc[df_orders_products_merged['prices'] > 15, 'price_label'] = 'High-range product'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['prices'] <= 15) & (df_orders_products_merged['prices'] > 5), 'price_label'] = 'Mid-range product'

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] <= 5, 'price_label'] = 'Low-range product'

# %%
df_orders_products_merged['price_label'].value_counts()
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_label, dtype: int64

# %%
#change column name
df_orders_products_merged.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_label
# ...

# %%
df_orders_products_merged['order_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# # If statement with for loop

# %%
#creating forloop by looking at order_day_of_week column to see busiest day vs least busy

result = []

for value in df_orders_products_merged["order_day_of_week"]:  
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#label column for this new column
df_orders_products_merged['Busiest_day'] = result

# %%
df_orders_products_merged['Busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: Busiest_day, dtype: int64

# %% [markdown]
# # 2 Busiest Days

# %%
#creating forloop by looking at order_day_of_week column to see busiest days vs least busy days (top 2) 

result_2 = []

for value in df_orders_products_merged["order_day_of_week"]:  
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Least busy days")
  else:
    result_2.append("Regularly busy days")

# %%
result_2
# Out:
# ['Regularly busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy days',
# ...

# %%
df_orders_products_merged['Busiest_days'] = result_2

# %%
df_orders_products_merged['Busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy days    12927461
# Busiest days           11875462
# Least busy days         7631289
# Name: Busiest_days, dtype: int64

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_label  \
# ...

# %% [markdown]
# # 4 Create busiest hours of day column

# %%
df_orders_products_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Most Orders: 10, 11, 14, 15, 13, 12, 16, 9
#
# Average Orders: 17, 8, 18, 19, 20, 7, 21, 22
#
# Fewest Orders: 23, 6, 0, 1, 5, 2, 4, 3

# %%
#creating forloop by looking at order_hour_of_day column to see busiest times vs least busy times  

result_3 = []

for value in df_orders_products_merged["order_hour_of_day"]:  
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    result_3.append("Most Orders")
  elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
    result_3.append("Average Orders")
  else:
    result_3.append("Fewest Orders")

# %%
result_3
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
# ...

# %%
df_orders_products_merged['Busiest_period_of_day'] = result_3

# %%
df_orders_products_merged['Busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most Orders       21137262
# Average Orders    10006752
# Fewest Orders      1290198
# Name: Busiest_period_of_day, dtype: int64

# %%
df_orders_products_merged.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
# 5   3367565        1             6                  2                  7
# 6    550135        1             7                  1                  9
# 7   3108588        1             8                  1                 14
# 8   2295261        1             9                  1                 16
# 9   2550362        1            10                  4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
# Export data to pkl

df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
